# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### Data Frame
# ###### Data obtained from wikipedia.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
#Reads the first table of wikipedia HTML 
Toronto_NB = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# %%
#Drop the Borough not assigned
Toronto_NB = Toronto_NB.drop(Toronto_NB[Toronto_NB['Borough'] == "Not assigned"].index)

# %%
Toronto_NB.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# ##### There are not Neighbourhoods with not assigned values

# %% [markdown]
# ## Second Excersice

# %%
Toronto_NB.shape
# Out:
# (103, 3)

# %%
df = pd.read_csv('http://cocl.us/Geospatial_data')
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Inner merge by postal code
merged_inner = pd.merge(left=Toronto_NB, right=df, left_on='Postal Code', right_on='Postal Code')
merged_inner.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ## Third Excersice

# %% [markdown]
# #### Libraries for map ploting

# %%
from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
# ...

# %%
map_Toronto = folium.Map(location=[43.7, -79.4], zoom_start=11)

for lat, lng, borough, neighborhood in zip(merged_inner['Latitude'], merged_inner['Longitude'], merged_inner['Borough'], merged_inner['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto) 

map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Libraries for clustering

# %%
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %%
print(merged_inner.groupby('Borough').size())
# Out:
# Borough
# Central Toronto      9
# Downtown Toronto    19
# East Toronto         5
# East York            5
# Etobicoke           12
# Mississauga          1
# North York          24
# Scarborough         17
# West Toronto         6
# York                 5
# dtype: int64

# %% [markdown]
# #### Making the clusters

# %%
z = merged_inner.groupby('Borough').size()
x = np.array(z[[0]])

# %%
kmeans = KMeans(n_clusters=5).fit(x)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-8f6fe0843cbb> in <module>
# ----> 1 kmeans = KMeans(n_clusters=5).fit(x)
#       2 centroids = kmeans.cluster_centers_
#       3 print(centroids)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     309     order = "C" if copy_x else None
# ...
